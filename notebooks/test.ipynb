# %%
# !pip install scikit-learn

# %%
# !pip install PyYAML

# %%
# !pip install scipy
# Out:
# ...
#   Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# ...
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/41.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/41.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/41.3 MB ? eta -:--:--
#     --------------------------------------- 0.5/41.3 MB 453.5 kB/s eta 0:01:30
#     --------------------------------------- 0.5/41.3 MB 453.5 kB/s eta 0:01:30
#     --------------------------------------- 0.5/41.3 MB 453.5 kB/s eta 0:01:30
#     --------------------------------------- 0.8/41.3 MB 441.7 kB/s eta 0:01:32
# ...

# %%
# git commit
